# %%
import vcs
x=vcs.init(bg=False)
gm = vcs.createboxfill()
import cdms2
import cdat_info
cdat_info.download_sample_data_files("Share/test_data_files.txt")
f = cdms2.open(cdat_info.get_sampledata_path()+"/clt.nc")
s=f("clt")
# Out:
# CAlling with bg: False
# Downloading: 'clt.nc' from 'http://uvcdat.llnl.gov/cdat/sample_data' in: /home/doutriaux1/anaconda2/envs/widgets3/share/cdat/sample_data/clt.nc
# Downloading: 'sampleCurveGrid4.nc' from 'http://uvcdat.llnl.gov/cdat/sample_data' in: /home/doutriaux1/anaconda2/envs/widgets3/share/cdat/sample_data/sampleCurveGrid4.nc
# Downloading: 'ta_ncep_87-6-88-4.nc' from 'http://uvcdat.llnl.gov/cdat/sample_data' in: /home/doutriaux1/anaconda2/envs/widgets3/share/cdat/sample_data/ta_ncep_87-6-88-4.nc
# Downloading: 'tas_ccsr-95a_1979.01-1979.12.nc' from 'http://uvcdat.llnl.gov/cdat/sample_data' in: /home/doutriaux1/anaconda2/envs/widgets3/share/cdat/sample_data/tas_ccsr-95a_1979.01-1979.12.nc
# Downloading: 'BlueMarble.ppm' from 'http://uvcdat.llnl.gov/cdat/sample_data' in: /home/doutriaux1/anaconda2/envs/widgets3/share/cdat/sample_data/BlueMarble.ppm

# %%
x.plot(s)

# %%
x.interact()
