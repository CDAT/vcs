# %% [markdown]
# # Notebook autogenerated by CDAT on 2018-10-15 07:32:13
#
# # Source file information
#
# Name: test_vcs_generate_simple_plot.png
#
# Generated on 2018-10-15 07:31:52
#
# By: doutriaux1
#
# Platform: loki Darwin (17.7.0)
#
#
# Generated via script, command line: `tests/share/vcs_generate_simple_plot.py`
#
# Script sources pasted bellow
#
#
# More information probably available in file's provenance dictionary

# %%
#!/usr/bin/env python
import vcs
x = vcs.init(bg=True)
x.plot([1,2,3,2,1,4,5,2,1,4])
x.png("test_vcs_generate_simple_plot", provenance=True)
